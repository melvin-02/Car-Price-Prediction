# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("car_data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
print(df['Fuel_Type'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]
# ['Petrol' 'Diesel' 'CNG']

# %%
# Check missing values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset = df[[ 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_dataset['Current_Year'] = 2020

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2020
# 1       Manual      0          2020
# 2       Manual      0          2020
# 3       Manual      0          2020
# 4       Manual      0          2020

# %%
final_dataset['Years_old'] = final_dataset['Current_Year'] - final_dataset['Year']

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  Years_old
# 0       Manual      0          2020          6
# 1       Manual      0          2020          7
# 2       Manual      0          2020          3
# 3       Manual      0          2020          9
# 4       Manual      0          2020          6

# %%
final_dataset.drop(['Year', 'Current_Year'], axis=1, inplace=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Years_old
# 0       Manual      0          6
# 1       Manual      0          7
# 2       Manual      0          3
# 3       Manual      0          9
# 4       Manual      0          6

# %%
final_dataset =pd.get_dummies(final_dataset, drop_first=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Years_old  \
# 0           3.35           5.59       27000      0          6
# 1           4.75           9.54       43000      0          7
# 2           7.25           9.85        6900      0          3
# 3           2.85           4.15        5200      0          9
# 4           4.60           6.87       42450      0          6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# Years_old                   -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         Years_old  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price           -0.236141          0.552339         -0.540571
# Present_Price            0.047584          0.473306         -0.465244
# Kms_Driven               0.524342          0.172515         -0.172874
# Owner                    0.182104         -0.053469          0.055687
# Years_old                1.000000         -0.064315          0.059959
# Fuel_Type_Diesel        -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol         0.059959         -0.979648          1.000000
# Seller_Type_Individual   0.039896         -0.350467          0.358321
# Transmission_Manual     -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.124269            -0.050316
# Years_old                             0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
sns.pairplot(final_dataset)

# %%
corrmat = final_dataset.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g = sns.heatmap(final_dataset[top_corr_features].corr(), annot=True, cmap='RdYlGn')

# %%
X = final_dataset.iloc[:, 1:]
y = final_dataset.iloc[:, 0]

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  Years_old  Fuel_Type_Diesel  \
# 0           5.59       27000      0          6                 0
# 1           9.54       43000      0          7                 1
# 2           9.85        6900      0          3                 0
# 3           4.15        5200      0          9                 0
# 4           6.87       42450      0          6                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
# Feature Importance
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor(n_estimators=100)
model.fit(X,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=None,
#                     max_features='auto', max_leaf_nodes=None,
#                     min_impurity_decrease=0.0, min_impurity_split=None,
#                     min_samples_leaf=1, min_samples_split=2,
#                     min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#                     oob_score=False, random_state=None, verbose=0,
#                     warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [0.38043018 0.04252591 0.00047035 0.07317804 0.22917153 0.00902023
#  0.13054899 0.13465477]

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (240, 8)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Hyperparameter Tunning
n_estimators = [int(x) for x in np.linspace(100, 1200, 12)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(5, 30, 6)]
min_samples_split = [2, 5, 10, 15, 100]
min_samples_leaf = [1, 2, 5, 10]

# %%
from sklearn.model_selection import RandomizedSearchCV
#bit faster than grid searchCV

# %%
random_grid = {'n_estimators':n_estimators,
              'max_features': max_features,
              'max_depth': max_depth,
              'min_samples_split': min_samples_split,
              'min_samples_leaf': min_samples_leaf,
              }
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# first create base model to tune
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator=rf,
                           param_distributions= random_grid,
                           n_iter = 10,
                           scoring = 'neg_mean_squared_error',
                           cv= 5,
                           verbose=2,
                           random_state=12)

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=   1.1s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=   1.0s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=   0.9s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=   1.0s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=10, max_features=sqrt, max_depth=20, total=   0.9s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   5.2s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   4.3s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   5.4s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   5.8s
# [CV] n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20
# [CV]  n_estimators=1200, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=20, total=   5.6s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   3.3s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   3.9s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   3.9s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   2.3s
# [CV] n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1100, min_samples_split=10, min_samples_leaf=10, max_features=sqrt, max_depth=15, total=   2.9s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   4.6s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   3.4s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   3.1s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   2.5s
# [CV] n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=15
# [CV]  n_estimators=1200, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=15, total=   2.8s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25, total=   2.3s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25, total=   2.1s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25, total=   1.9s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25, total=   1.8s
# [CV] n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25
# [CV]  n_estimators=800, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=25, total=   2.0s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.2s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.2s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   0.6s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   0.6s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   0.7s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   0.6s
# [CV] n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=5
# [CV]  n_estimators=300, min_samples_split=15, min_samples_leaf=1, max_features=sqrt, max_depth=5, total=   0.6s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=5, total=   0.7s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=5, total=   0.4s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=5, total=   0.5s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=5, total=   0.5s
# [CV] n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=5
# [CV]  n_estimators=200, min_samples_split=100, min_samples_leaf=1, max_features=auto, max_depth=5, total=   0.5s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.4s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.1s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.1s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.0s
# [CV] n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=600, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   1.2s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   2.0s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   1.9s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   2.0s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   2.1s
# [CV] n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=5
# [CV]  n_estimators=1100, min_samples_split=100, min_samples_leaf=5, max_features=sqrt, max_depth=5, total=   1.9s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  1.6min finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators='warn',
#                                                    n_jobs=None, oob_score=False,
#                                                    random_sta...
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    pre_dispatch='2*n_jobs', random_state=12, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
predictions = rf_random.predict(X_test)

# %%
predictions
# Out:
# array([10.68599126,  7.77713875,  0.65145895,  8.06917108,  1.16168958,
#         3.13850233,  0.47107914,  0.67697231,  7.21648722,  4.48246772,
#         4.01067818,  1.20400024,  3.04283945,  4.79278112,  2.20621783,
#         0.23044901,  3.30219539,  0.22636294,  6.10681896,  0.17831051,
#         8.25706633,  5.34993734,  4.23460283, 10.21823987,  4.85961931,
#        18.51558362,  0.58466966,  5.50409116,  6.09638346,  5.59340874,
#         1.16241316,  7.15240505,  3.6523141 ,  5.3275318 ,  9.498565  ,
#        17.85983832,  0.45328241,  3.96193996,  3.03031643,  0.46442625,
#         1.8459937 ,  9.01411263,  0.58089369,  4.85043036,  6.08788562,
#         3.78430733,  0.61151901,  0.4305166 ,  0.26498168,  3.22327978,
#         6.70281826,  0.34995508,  4.97567329,  3.77211131,  5.53821417,
#         1.19066598,  0.23131736,  5.06565578,  0.52024962,  0.69080426,
#         6.72763805])

# %%
sns.distplot(y_test - predictions)

# %%
plt.scatter(y_test, predictions)
plt.xlabel("y_test")
plt.ylabel("predictions")
# Out:
# Text(0, 0.5, 'predictions')

# %%
import pickle
# open a file where you want to store the data
file = open('car_price_prediction.pkl', 'wb')

pickle.dump(rf_random, file)
